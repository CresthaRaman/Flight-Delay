# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sriharshaeedala/airline-delay")

print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\sthar\.cache\kagglehub\datasets\sriharshaeedala\airline-delay\1.archive...
# 100%|██████████| 6.44M/6.44M [00:02<00:00, 3.21MB/s]
# Extracting files...
# Path to dataset files: C:\Users\sthar\.cache\kagglehub\datasets\sriharshaeedala\airline-delay\versions\1

# %%
import pandas as pd

df = pd.read_csv("Airline_Delay_Cause.csv")
